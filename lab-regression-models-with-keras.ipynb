# %% [markdown]
# <h1>Regression Models with Keras</h1>
#
# Objective for this Notebook
#
# - How to use the Tensorflow API, Keras, to build a regression model.
# - Download and Clean dataset
# - Build a Neural Network
# - rain and Test the Network

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Download and Clean Dataset</a>
# 2. <a href="#item32">Import Keras</a>
# 3. <a href="#item33">Build a Neural Network</a>
# 4. <a href="#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id="item31"></a>

# %% [markdown]
# ## Download and Clean Dataset

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# <strong>1. Cement</strong>
#
# <strong>2. Blast Furnace Slag</strong>
#
# <strong>3. Fly Ash</strong>
#
# <strong>4. Water</strong>
#
# <strong>5. Superplasticizer</strong>
#
# <strong>6. Coarse Aggregate</strong>
#
# <strong>7. Fine Aggregate</strong>

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have.

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ## Import Keras

# %% [markdown]
# Recall from the videos that Keras normally runs on top of a low-level library such as TensorFlow. This means that to be able to use the Keras library, you will have to install TensorFlow first and when you import the Keras library, it will be explicitly displayed what backend was used to install the Keras library. In CC Labs, we used TensorFlow as the backend to install Keras, so it should clearly print that when we import Keras.

# %% [markdown]
# #### Let's go ahead and import the Keras library

# %%
from tensorflow import keras

# %% [markdown]
# As you can see, the TensorFlow backend was used to install the Keras library.

# %% [markdown]
# Let's import the rest of the packages from the Keras library that we will need to build our regressoin model.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    """
    1. Initialize a sequential model
    2. Add 2 dense layers with a relu activation function and 50 neurons each
    3. Add a final dense layer with a single neuron for the output (since it's a regression task)
    """
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))  # Final layer for regression output

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# <a id='item34'></a>

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 3s - loss: 1625.8739 - val_loss: 1124.3674 - 3s/epoch - 123ms/step
# Epoch 2/100
# 23/23 - 0s - loss: 1467.4839 - val_loss: 971.9091 - 229ms/epoch - 10ms/step
# Epoch 3/100
# 23/23 - 0s - loss: 1219.4056 - val_loss: 751.2964 - 222ms/epoch - 10ms/step
# Epoch 4/100
# 23/23 - 0s - loss: 878.2593 - val_loss: 493.8819 - 257ms/epoch - 11ms/step
# Epoch 5/100
# 23/23 - 0s - loss: 523.7273 - val_loss: 286.2204 - 276ms/epoch - 12ms/step
# Epoch 6/100
# 23/23 - 0s - loss: 306.9489 - val_loss: 189.1356 - 177ms/epoch - 8ms/step
# Epoch 7/100
# 23/23 - 0s - loss: 233.9122 - val_loss: 174.3251 - 178ms/epoch - 8ms/step
# Epoch 8/100
# 23/23 - 0s - loss: 215.2704 - val_loss: 174.3387 - 186ms/epoch - 8ms/step
# Epoch 9/100
# 23/23 - 0s - loss: 203.2096 - val_loss: 170.7722 - 257ms/epoch - 11ms/step
# Epoch 10/100
# 23/23 - 0s - loss: 194.7085 - val_loss: 167.8108 - 123ms/epoch - 5ms/step
# Epoch 11/100
# 23/23 - 0s - loss: 189.4697 - val_loss: 166.5070 - 162ms/epoch - 7ms/step
# Epoch 12/100
# 23/23 - 0s - loss: 182.2150 - val_loss: 161.0845 - 247ms/epoch - 11ms/step
# Epoch 13/100
# 23/23 - 0s - loss: 177.6910 - val_loss: 159.5307 - 186ms/epoch - 8ms/step
# Epoch 14/100
# 23/23 - 0s - loss: 173.2418 - val_loss: 157.6258 - 271ms/epoch - 12ms/step
# Epoch 15/100
# 23/23 - 0s - loss: 170.0292 - val_loss: 157.3589 - 115ms/epoch - 5ms/step
# Epoch 16/100
# 23/23 - 0s - loss: 166.9276 - val_loss: 153.9201 - 149ms/epoch - 6ms/step
# Epoch 17/100
# 23/23 - 0s - loss: 163.8033 - val_loss: 151.0117 - 134ms/epoch - 6ms/step
# Epoch 18/100
# 23/23 - 0s - loss: 161.6257 - val_loss: 148.3589 - 151ms/epoch - 7ms/step
# Epoch 19/100
# 23/23 - 0s - loss: 159.5450 - val_loss: 150.3838 - 219ms/epoch - 10ms/step
# Epoch 20/100
# 23/23 - 0s - loss: 157.0530 - val_loss: 150.1126 - 153ms/epoch - 7ms/step
# Epoch 21/100
# 23/23 - 0s - loss: 154.6184 - val_loss: 147.3787 - 85ms/epoch - 4ms/step
# Epoch 22/100
# 23/23 - 0s - loss: 153.9865 - val_loss: 147.1051 - 83ms/epoch - 4ms/step
# Epoch 23/100
# 23/23 - 0s - loss: 151.3099 - val_loss: 144.6756 - 98ms/epoch - 4ms/step
# Epoch 24/100
# 23/23 - 0s - loss: 149.4286 - val_loss: 145.5668 - 99ms/epoch - 4ms/step
# Epoch 25/100
# 23/23 - 0s - loss: 148.1985 - val_loss: 146.0259 - 117ms/epoch - 5ms/step
# Epoch 26/100
# 23/23 - 0s - loss: 147.1198 - val_loss: 146.2891 - 99ms/epoch - 4ms/step
# Epoch 27/100
# 23/23 - 0s - loss: 145.5098 - val_loss: 145.6534 - 109ms/epoch - 5ms/step
# Epoch 28/100
# 23/23 - 0s - loss: 144.4206 - val_loss: 145.3449 - 104ms/epoch - 5ms/step
# Epoch 29/100
# 23/23 - 0s - loss: 143.2744 - val_loss: 144.5875 - 106ms/epoch - 5ms/step
# Epoch 30/100
# 23/23 - 0s - loss: 141.8805 - val_loss: 145.4981 - 100ms/epoch - 4ms/step
# Epoch 31/100
# 23/23 - 0s - loss: 140.7084 - val_loss: 144.5232 - 95ms/epoch - 4ms/step
# Epoch 32/100
# 23/23 - 0s - loss: 139.4950 - val_loss: 144.4999 - 153ms/epoch - 7ms/step
# Epoch 33/100
# 23/23 - 0s - loss: 138.4989 - val_loss: 146.2070 - 192ms/epoch - 8ms/step
# Epoch 34/100
# 23/23 - 0s - loss: 137.6125 - val_loss: 147.0803 - 181ms/epoch - 8ms/step
# Epoch 35/100
# 23/23 - 0s - loss: 136.5585 - val_loss: 145.8909 - 161ms/epoch - 7ms/step
# Epoch 36/100
# 23/23 - 0s - loss: 136.5103 - val_loss: 147.0334 - 174ms/epoch - 8ms/step
# Epoch 37/100
# 23/23 - 0s - loss: 135.2044 - val_loss: 145.5392 - 203ms/epoch - 9ms/step
# Epoch 38/100
# 23/23 - 0s - loss: 134.8352 - val_loss: 146.3531 - 154ms/epoch - 7ms/step
# Epoch 39/100
# 23/23 - 0s - loss: 133.0371 - val_loss: 145.6461 - 167ms/epoch - 7ms/step
# Epoch 40/100
# 23/23 - 0s - loss: 131.9945 - val_loss: 147.9936 - 187ms/epoch - 8ms/step
# Epoch 41/100
# 23/23 - 0s - loss: 131.0425 - val_loss: 146.7558 - 212ms/epoch - 9ms/step
# Epoch 42/100
# 23/23 - 0s - loss: 129.8747 - val_loss: 146.7937 - 191ms/epoch - 8ms/step
# Epoch 43/100
# 23/23 - 0s - loss: 129.3052 - val_loss: 147.0892 - 196ms/epoch - 9ms/step
# Epoch 44/100
# 23/23 - 0s - loss: 128.2825 - val_loss: 149.1497 - 165ms/epoch - 7ms/step
# Epoch 45/100
# 23/23 - 0s - loss: 127.3553 - val_loss: 148.4948 - 114ms/epoch - 5ms/step
# Epoch 46/100
# 23/23 - 0s - loss: 126.3362 - val_loss: 147.1599 - 149ms/epoch - 6ms/step
# Epoch 47/100
# 23/23 - 0s - loss: 126.3795 - val_loss: 147.3854 - 133ms/epoch - 6ms/step
# Epoch 48/100
# 23/23 - 0s - loss: 124.5563 - val_loss: 148.1070 - 122ms/epoch - 5ms/step
# Epoch 49/100
# 23/23 - 0s - loss: 123.6028 - val_loss: 150.4374 - 118ms/epoch - 5ms/step
# Epoch 50/100
# 23/23 - 0s - loss: 122.4862 - val_loss: 148.7489 - 95ms/epoch - 4ms/step
# Epoch 51/100
# 23/23 - 0s - loss: 121.4696 - val_loss: 149.0271 - 73ms/epoch - 3ms/step
# Epoch 52/100
# 23/23 - 0s - loss: 120.5413 - val_loss: 149.2557 - 81ms/epoch - 4ms/step
# Epoch 53/100
# 23/23 - 0s - loss: 119.9534 - val_loss: 147.1637 - 83ms/epoch - 4ms/step
# Epoch 54/100
# 23/23 - 0s - loss: 119.3097 - val_loss: 150.3616 - 75ms/epoch - 3ms/step
# Epoch 55/100
# 23/23 - 0s - loss: 118.2274 - val_loss: 148.3015 - 83ms/epoch - 4ms/step
# Epoch 56/100
# 23/23 - 0s - loss: 116.6400 - val_loss: 147.1053 - 82ms/epoch - 4ms/step
# Epoch 57/100
# 23/23 - 0s - loss: 115.0183 - val_loss: 149.8096 - 73ms/epoch - 3ms/step
# Epoch 58/100
# 23/23 - 0s - loss: 114.1392 - val_loss: 149.5265 - 87ms/epoch - 4ms/step
# Epoch 59/100
# 23/23 - 0s - loss: 112.3476 - val_loss: 148.8171 - 73ms/epoch - 3ms/step
# Epoch 60/100
# 23/23 - 0s - loss: 111.1146 - val_loss: 147.3333 - 83ms/epoch - 4ms/step
# Epoch 61/100
# 23/23 - 0s - loss: 109.8234 - val_loss: 145.3534 - 82ms/epoch - 4ms/step
# Epoch 62/100
# 23/23 - 0s - loss: 108.1167 - val_loss: 146.7260 - 81ms/epoch - 4ms/step
# Epoch 63/100
# 23/23 - 0s - loss: 106.4339 - val_loss: 141.6825 - 82ms/epoch - 4ms/step
# Epoch 64/100
# 23/23 - 0s - loss: 104.6584 - val_loss: 142.9230 - 83ms/epoch - 4ms/step
# Epoch 65/100
# 23/23 - 0s - loss: 102.9867 - val_loss: 145.4693 - 73ms/epoch - 3ms/step
# Epoch 66/100
# 23/23 - 0s - loss: 102.1078 - val_loss: 143.1442 - 76ms/epoch - 3ms/step
# Epoch 67/100
# 23/23 - 0s - loss: 99.5843 - val_loss: 141.1445 - 74ms/epoch - 3ms/step
# Epoch 68/100
# 23/23 - 0s - loss: 97.6639 - val_loss: 140.4896 - 80ms/epoch - 3ms/step
# Epoch 69/100
# 23/23 - 0s - loss: 95.4663 - val_loss: 138.9731 - 82ms/epoch - 4ms/step
# Epoch 70/100
# 23/23 - 0s - loss: 93.8747 - val_loss: 140.9271 - 82ms/epoch - 4ms/step
# Epoch 71/100
# 23/23 - 0s - loss: 91.6491 - val_loss: 135.8629 - 94ms/epoch - 4ms/step
# Epoch 72/100
# 23/23 - 0s - loss: 89.5128 - val_loss: 139.0810 - 81ms/epoch - 4ms/step
# Epoch 73/100
# 23/23 - 0s - loss: 87.3524 - val_loss: 133.5670 - 84ms/epoch - 4ms/step
# Epoch 74/100
# 23/23 - 0s - loss: 85.7038 - val_loss: 138.1742 - 74ms/epoch - 3ms/step
# Epoch 75/100
# 23/23 - 0s - loss: 84.0488 - val_loss: 131.9034 - 83ms/epoch - 4ms/step
# Epoch 76/100
# 23/23 - 0s - loss: 81.9240 - val_loss: 134.7866 - 76ms/epoch - 3ms/step
# Epoch 77/100
# 23/23 - 0s - loss: 79.8429 - val_loss: 129.6684 - 84ms/epoch - 4ms/step
# Epoch 78/100
# 23/23 - 0s - loss: 77.3018 - val_loss: 130.0732 - 79ms/epoch - 3ms/step
# Epoch 79/100
# 23/23 - 0s - loss: 75.8366 - val_loss: 128.3647 - 76ms/epoch - 3ms/step
# Epoch 80/100
# 23/23 - 0s - loss: 73.8056 - val_loss: 126.6274 - 80ms/epoch - 3ms/step
# Epoch 81/100
# 23/23 - 0s - loss: 71.8208 - val_loss: 125.4386 - 81ms/epoch - 4ms/step
# Epoch 82/100
# 23/23 - 0s - loss: 70.6641 - val_loss: 122.8060 - 74ms/epoch - 3ms/step
# Epoch 83/100
# 23/23 - 0s - loss: 69.2865 - val_loss: 123.2150 - 100ms/epoch - 4ms/step
# Epoch 84/100
# 23/23 - 0s - loss: 67.3160 - val_loss: 122.7685 - 84ms/epoch - 4ms/step
# Epoch 85/100
# 23/23 - 0s - loss: 65.2662 - val_loss: 115.3435 - 79ms/epoch - 3ms/step
# Epoch 86/100
# 23/23 - 0s - loss: 64.0387 - val_loss: 117.8475 - 76ms/epoch - 3ms/step
# Epoch 87/100
# 23/23 - 0s - loss: 63.0085 - val_loss: 113.4265 - 90ms/epoch - 4ms/step
# Epoch 88/100
# 23/23 - 0s - loss: 60.4769 - val_loss: 119.9435 - 95ms/epoch - 4ms/step
# Epoch 89/100
# 23/23 - 0s - loss: 60.2557 - val_loss: 113.4990 - 108ms/epoch - 5ms/step
# Epoch 90/100
# 23/23 - 0s - loss: 59.1458 - val_loss: 118.9699 - 88ms/epoch - 4ms/step
# Epoch 91/100
# 23/23 - 0s - loss: 57.5040 - val_loss: 113.8219 - 97ms/epoch - 4ms/step
# Epoch 92/100
# 23/23 - 0s - loss: 56.5536 - val_loss: 117.0860 - 110ms/epoch - 5ms/step
# Epoch 93/100
# 23/23 - 0s - loss: 55.8472 - val_loss: 113.3430 - 115ms/epoch - 5ms/step
# Epoch 94/100
# 23/23 - 0s - loss: 54.7321 - val_loss: 112.4486 - 102ms/epoch - 4ms/step
# Epoch 95/100
# 23/23 - 0s - loss: 54.6099 - val_loss: 115.7063 - 114ms/epoch - 5ms/step
# Epoch 96/100
# 23/23 - 0s - loss: 53.6493 - val_loss: 113.7776 - 101ms/epoch - 4ms/step
# Epoch 97/100
# 23/23 - 0s - loss: 52.9900 - val_loss: 109.9614 - 98ms/epoch - 4ms/step
# Epoch 98/100
# 23/23 - 0s - loss: 51.7770 - val_loss: 116.7805 - 100ms/epoch - 4ms/step
# Epoch 99/100
# 23/23 - 0s - loss: 51.2563 - val_loss: 116.2131 - 87ms/epoch - 4ms/step
# Epoch 100/100
# 23/23 - 0s - loss: 50.5507 - val_loss: 106.7012 - 92ms/epoch - 4ms/step

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork945-2022-01-01) to learn about other functions that you can use for prediction or evaluation.</strong>

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# ### Thank you for completing this lab!
